# %%
import pandas as pd
df=pd.read_csv('my_data/survey_results_public.csv')
df
# Out:
#        Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0               1  I am a developer by profession      Yes  NaN         13
# 1               2  I am a developer by profession       No  NaN         19
# 2               3     I code primarily as a hobby      Yes  NaN         15
# ...           ...                             ...      ...  ...        ...
# 64458       64898                             NaN      Yes  NaN        NaN
# 64459       64925                             NaN      Yes  NaN        NaN
# 64460       65112                             NaN      Yes  NaN        NaN
#
#       CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0      Monthly        NaN            NaN             Germany   European Euro
# 1          NaN        NaN            NaN      United Kingdom  Pound sterling
# 2          NaN        NaN            NaN  Russian Federation             NaN
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
pd.set_option('display.max_columns',61)

# %%
pd.set_option('display.max_rows',6)

# %%
schema_df=pd.read_csv('my_data/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# ..           ...                                                ...
# 58   WorkWeekHrs  On average, how many hours per week do you wor...
# 59     YearsCode  Including any education, how many years have y...
# 60  YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
people={
    "first" : ["jai","sai","shankar"],
    "last" : ["kona","kota","kalla"],
    "email" : ["abc@gmail.com","xyz@gmail.com","sai@gmail.com"]
}

# %%
df=pd.DataFrame(people)

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#      first   last          email
# 0      jai   kona  abc@gmail.com
# 1      sai   kota  xyz@gmail.com
# 2  shankar  kalla  sai@gmail.com

# %%
df["email"]
# Out:
# 0    abc@gmail.com
# 1    xyz@gmail.com
# 2    sai@gmail.com
# Name: email, dtype: object

# %%
df[["first","email"]]
# Out:
#      first          email
# 0      jai  abc@gmail.com
# 1      sai  xyz@gmail.com
# 2  shankar  sai@gmail.com

# %%
df.iloc[0]
# Out:
# first              jai
# last              kona
# email    abc@gmail.com
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# first              jai
# last              kona
# email    abc@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#   first  last          email
# 0   jai  kona  abc@gmail.com
# 1   sai  kota  xyz@gmail.com

# %%
df.iloc[[0,1],2]
# Out:
# 0    abc@gmail.com
# 1    xyz@gmail.com
# Name: email, dtype: object

# %%
import pandas as pd

# %%
df=pd.read_csv('my_data/survey_results_public.csv')
df
# Out:
#        Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0               1  I am a developer by profession      Yes  NaN         13
# 1               2  I am a developer by profession       No  NaN         19
# 2               3     I code primarily as a hobby      Yes  NaN         15
# ...           ...                             ...      ...  ...        ...
# 64458       64898                             NaN      Yes  NaN        NaN
# 64459       64925                             NaN      Yes  NaN        NaN
# 64460       65112                             NaN      Yes  NaN        NaN
#
#       CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  \
# 0      Monthly        NaN            NaN             Germany   European Euro
# 1          NaN        NaN            NaN      United Kingdom  Pound sterling
# 2          NaN        NaN            NaN  Russian Federation             NaN
# ...

# %%
pd.set_option('display.max_columns',61)

# %%
pd.set_option('display.max_rows',61)

# %%
schema_df=pd.read_csv('my_data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_df.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# 25.0    2693
# 28.0    2412
# 30.0    2406
# 26.0    2391
# 27.0    2338
#         ...
# 34.5       1
# 14.7       1
# 97.0       1
# 3.0        1
# 14.5       1
# Name: Age, Length: 110, dtype: int64

# %%
df.iloc[[0,1,2],2]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
people
# Out:
# {'first': ['jai', 'sai', 'shankar'],
#  'last': ['kona', 'kota', 'kalla'],
#  'email': ['abc@gmail.com', 'xyz@gmail.com', 'sai@gmail.com']}

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#      first   last          email
# 0      jai   kona  abc@gmail.com
# 1      sai   kota  xyz@gmail.com
# 2  shankar  kalla  sai@gmail.com

# %%
df
# Out:
#      first   last          email
# 0      jai   kona  abc@gmail.com
# 1      sai   kota  xyz@gmail.com
# 2  shankar  kalla  sai@gmail.com

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[1,2,3,6,85,7,4]
plt.plot(x,y)
plt.show()
